# %%
import numpy 
import pandas
import json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/4m/b6_cz0w13g31tffdygtbhty00000gn/T/ipykernel_29905/111863382.py in <module>
#       1 import numpy
# ----> 2 import pandas
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip freeze
# Out:
# appnope @ file:///home/conda/feedstock_root/build_artifacts/appnope_1707233003401/work
# backcall @ file:///home/conda/feedstock_root/build_artifacts/backcall_1592338393461/work
# backports.functools-lru-cache @ file:///home/conda/feedstock_root/build_artifacts/backports.functools_lru_cache_1702571698061/work
# certifi @ file:///home/conda/feedstock_root/build_artifacts/certifi_1725278078093/work/certifi
# cycler==0.11.0
# debugpy @ file:///Users/runner/miniforge3/conda-bld/debugpy_1660619094083/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1643888246732/work
# fonttools==4.38.0
# ipykernel @ file:///Users/runner/miniforge3/conda-bld/ipykernel_1666723502644/work
# ipython @ file:///Users/runner/miniforge3/conda-bld/ipython_1651240787717/work
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1696326070614/work
# ...

# %%
# !pip install pandas==2.1.4
# Out:
# ERROR: Ignored the following versions that require a different python version: 1.4.0 Requires-Python >=3.8; 1.4.1 Requires-Python >=3.8; 1.4.2 Requires-Python >=3.8; 1.4.3 Requires-Python >=3.8; 1.4.4 Requires-Python >=3.8; 1.5.0 Requires-Python >=3.8; 1.5.1 Requires-Python >=3.8; 1.5.2 Requires-Python >=3.8; 1.5.3 Requires-Python >=3.8; 2.0.0 Requires-Python >=3.8; 2.0.1 Requires-Python >=3.8; 2.0.2 Requires-Python >=3.8; 2.0.3 Requires-Python >=3.8; 2.1.0 Requires-Python >=3.9; 2.1.1 Requires-Python >=3.9; 2.1.2 Requires-Python >=3.9; 2.1.3 Requires-Python >=3.9; 2.1.4 Requires-Python >=3.9; 2.2.0 Requires-Python >=3.9; 2.2.1 Requires-Python >=3.9; 2.2.2 Requires-Python >=3.9; 2.2.3 Requires-Python >=3.9; 2.3.0 Requires-Python >=3.9; 2.3.1 Requires-Python >=3.9; 2.3.2 Requires-Python >=3.9; 2.3.3 Requires-Python >=3.9; 3.0.0 Requires-Python >=3.11; 3.0.0rc0 Requires-Python >=3.11; 3.0.0rc1 Requires-Python >=3.11; 3.0.0rc2 Requires-Python >=3.11; 3.0.1 Requires-Python >=3.11; 3.0.2 
# ...
