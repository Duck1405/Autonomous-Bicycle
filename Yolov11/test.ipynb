# %%
from inference import get_model
import supervision as sv
from inference.core.utils.image_utils import load_image_bgr
 
# image = load_image_bgr("https://media.roboflow.com/inference/vehicles.png")
# model = get_model(model_id="yolo11x-640")
# results = model.infer(image)[0]
# results = sv.Detections.from_inference(results)
# annotator = sv.BoxAnnotator(thickness=4)
# annotated_image = annotator.annotate(image, results)
# annotator = sv.LabelAnnotator(text_scale=2, text_thickness=2)
# annotated_image = annotator.annotate(annotated_image, results)
# sv.plot_image(annotated_image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from inference import get_model
#       2 import supervision as sv
#       3 from inference.core.utils.image_utils import load_image_bgr
#
# ModuleNotFoundError: No module named 'inference'

# %%
from ultralytics import YOLO

# model_n = YOLO("models/yolo11n.pt")
# model_s = YOLO("models/yolo11s.pt")

# metrics = model_n("dataset/Original/train/images/000000581903_jpg.rf.11bf759f4e640c0feadac80b25d1d0d2.jpg")
# metrics2 = model_s("dataset/Original/train/images/000000581903_jpg.rf.11bf759f4e640c0feadac80b25d1d0d2.jpg")
# Out:
# image 1/1 /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/Original/train/images/000000581903_jpg.rf.11bf759f4e640c0feadac80b25d1d0d2.jpg: 640x640 10 bottles, 1 cup, 91.5ms
# Speed: 3.3ms preprocess, 91.5ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/Original/train/images/000000581903_jpg.rf.11bf759f4e640c0feadac80b25d1d0d2.jpg: 640x640 3 suitcases, 10 bottles, 100.7ms
# Speed: 2.1ms preprocess, 100.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
metrics[0].show()

# %%
metrics2[0].show()

# %%
import argparse
import json
from collections import Counter, defaultdict
from pathlib import Path
import sys


    
    
def get_files(segment_folder):
    return [path for path in segment_folder.iterdir() if path.is_file()]
def get_directories(cipo_path):
    return [path for path in cipo_path.iterdir() if path.is_dir()]
def remove_first_parent(path: Path) -> Path:
    return Path(*path.parts[1:])
def check_dir(check):
    if check.is_dir():
        print(f"Directory Found: {check}")
        return True
    else:
        print(f"Directory Not Found: {check}")
        return False
def check_file(check):
    if check.is_file():
        print(f"File Found: {check}")
    else:
        print("File Not Found")
    
    
def load_json(file):
    with open(file, 'r') as f:
        return json.load(f)

def split_dataset(coco_root, dst_root):
    print("split_dataset")
    print(coco_root)
    print(dst_root)
    annotation = coco_root / "annotations"
    train2017 = coco_root / "train2017"
    val2017 = coco_root / "val2017"
    if check_dir(annotation) == False:
        sys.exit()
    if check_dir(train2017) == False:
        sys.exit()
    if check_dir(val2017) == False:
        sys.exit()
        
    train_json_file = annotation / "instances_train2017.json"
    val_json_file = annotation / "instances_val2017.json"
        
    train2017_json = load_json(train_json_file)
    val2017_json = load_json(val_json_file)
    
    return train2017_json, val2017_json, train2017, val2017
    
    # print(f"Keys: {train2017_json.keys()}")
    # k = train2017_json.keys()
    
    # print()
    
    
    
    
    
    
    # print(train2017_json[train2017_json.keys()[0]])
    

    # for i in train2017_json.keys():
    #     print(f"i: {i}, len(train2017_json[{i}]): {len(train2017_json[i]}")
    





# parser = argparse.ArgumentParser()
# parser.add_argument("--coco-root", default="dataset",help="dir containing annotations/, train2017/, val2017/")
# parser.add_argument("--dst", default="dataset/coco4", help="output dataset root")
# args = parser.parse_args()
coco_root = Path("dataset").resolve()
print(f"coco_root: {coco_root}")
dst_root = Path("dataset/coco4").resolve()
print(f"dst_root: {dst_root}")
train_json, val_json, train_folder, val_folder = split_dataset(coco_root, dst_root)
# Out:
# coco_root: /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset
# dst_root: /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/coco4
# split_dataset
# /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset
# /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/coco4
# Directory Found: /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/annotations
# Directory Found: /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/train2017
# Directory Found: /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/val2017

# %%
print(train_folder)
print(val_folder)
# Out:
# /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/train2017
# /Users/amannindra/Projects/Auto/Autonomous-Bicycle/Yolov11/dataset/val2017

# %%
print(train_json["annotations"][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(train_json["annotations"][0])
#
# NameError: name 'train_json' is not defined

# %%
print(train_json.keys())
print(val_json.keys())

print(train_json["annotations"][0])

l = [3, 8, 10, 13]

for i in range(len(train_json["annotations"])):
    if train_json["annotations"][i]["category_id"] in l:
        image_id = train_json["annotations"][i]["image_id"]
        
        
        
        
        


# print(train_json["images"][0])


# print(train_json["images"][0].keys())

# print(train_json["images"][0]['file_name'])

# test_file = train_json["images"][0]['file_name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(train_json.keys())
#       2 print(val_json.keys())
#       4 print(train_json["annotations"][0])
#
# NameError: name 'train_json' is not defined

# %%
# print(train_json["images"][0])


# print(train_json["images"][0].keys())

# print(train_json["images"][0]['file_name'])

# test_file = train_json["images"][0]['file_name']

# %%
train_json["images"][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 train_json["images"][0]
#
# NameError: name 'train_json' is not defined

# %%
# print(get_files(train_folder)[:100])
