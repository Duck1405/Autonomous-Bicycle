# %%
# !pip install -r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt
# Out:
# Requirement already satisfied: numpy==1.21.6 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from -r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 1)) (1.21.6)
# Requirement already satisfied: opencv-python==4.5.5.62 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from -r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 2)) (4.5.5.62)
# Requirement already satisfied: matplotlib==3.5.3 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from -r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (9.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (2.9.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (3.1.4)
# Requirement already satisfied: packaging>=20.0 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (23.2)
# Requirement already satisfied: typing-extensions in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (4.7.1)
# Requirement already satisfied: six>=1.5 in /Users/amannindra/miniconda3/envs/hybridnets-3.7-automation/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib==3.5.3->-r /Users/amannindra/Projects/Autonomous-Bicycle/Send/requirements-autonomation.txt (line 3)) (1.16.0)

# %%
import numpy as np
import cv2
from video_common import (
    DEFAULT_OUTPUT,
    DEFAULT_VIDEO,
    DEFAULT_WEIGHTS,
    parse_bool,
    preprocess_frame,
)
from matplotlib import matplotlib.pyplots
# Out:
#   File "/var/folders/4m/b6_cz0w13g31tffdygtbhty00000gn/T/ipykernel_30915/875267326.py", line 10
#     from matplotlib import matplotlib.pyplots
#                                      ^
# SyntaxError: invalid syntax

# %%
print(np.__version__)
print(cv2.__version__)
print(m)
# Out:
# 1.21.6
# 4.5.5

# %%
numpy_file = np.load("/Users/amannindra/Projects/Autonomous-Bicycle/Send/numpy_output/IMG_5098_30sec_prediction.npy")
video_file = cv2.VideoCapture("/Users/amannindra/Projects/Autonomous-Bicycle/Send/numpy_videos/IMG_5098(30sec).mp4")

# %%
print(f"unique: {str(np.unique(numpy_file))}")
# Out:
# unique: [0 1 2]

# %%
numpy_file.shape
# Out:
# (1045, 384, 640)

# %%
total_frames = int(video_file.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total Frames: {total_frames}")
# Out:
# Total Frames: 1045

# %%
success, frame = video_file.read()

frame.shape
# Out:
# (1080, 1920, 3)

# %%
def run_model_and_overlay(frame):
    overlay = frame.copy()

    overlay[seg == 1] = (0, 255, 0)      # road
    overlay[seg == 2] = (0, 0, 255)      # lane edge

    result = cv2.addWeighted(
        frame,
        0.7,      # original image weight
        overlay,
        0.3,      # mask weight
        0
    )

# %%
video_width = 1080
video_hiegh = 1920
output_height = 384
output_width = 640
fps = 30
output_path = "numpy_videos_concat"

writer = cv2.VideoWriter(
    output_path,
    cv2.VideoWriter_fourcc(*'mp4v'),
    fps,
    (width, height)
)


while True:
    ok, frame_bgr = video_file.read()
    if not ok:
        print(f"Error")
        break
    input_array, output_array = preprocess_frame(
            frame_bgr,
            video_width,
            video_hiegh,
            output_width,
            output_height,
        )
    print(input_array.shape)
    print(output_array.shape)
    
    result = run_model_and_overlay(input_array)
    writer.write(frame)
    
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4m/b6_cz0w13g31tffdygtbhty00000gn/T/ipykernel_30915/3670964889.py in <module>
#      10     cv2.VideoWriter_fourcc(*'mp4v'),
#      11     fps,
# ---> 12     (width, height)
#      13 )
#      14
#
# NameError: name 'width' is not defined
