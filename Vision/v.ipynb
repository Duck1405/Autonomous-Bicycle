# %%
# !pip install --upgrade pip
# !pip3 install openpifpaf
# Out:
# ...
#   Using cached openpifpaf-0.13.11.tar.gz (202 kB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × installing build dependencies for openpifpaf did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
# ...
#         Using cached setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
#       ERROR: Could not find a version that satisfies the requirement torch==1.13.1 (from versions: 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
#       ERROR: No matching distribution found for torch==1.13.1
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'openpifpaf' when installing build dependencies for openpifpaf
