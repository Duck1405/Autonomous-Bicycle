# %%
import torch
from pathlib import Path

# %%
# 1. Check core CUDA availability
cuda_available = torch.cuda.is_available()
print(f"Is CUDA available?: {cuda_available}")

if cuda_available:
    # 2. Get the number of available GPUs
    print(f"Number of GPUs: {torch.cuda.device_count()}")
    
    # 3. Get the name of the current GPU
    print(f"Current GPU Name: {torch.cuda.get_device_name(0)}")
    
    # 4. Check the CUDA version PyTorch was built with
    print(f"PyTorch CUDA Version: {torch.version.cuda}")
    
    # 5. Automatically assign device to GPU
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(f"Using device: {device}")
# Out:
# Is CUDA available?: True
# Number of GPUs: 1
# Current GPU Name: Orin
# PyTorch CUDA Version: 12.4
# Using device: cuda

# %%
import numpy

# %%
numpy.__version__
# Out:
# '2.4.4'

# %%
from pathlib import Path

# %%
ROOT = Path(__file__).resolve().parent
print(ROOT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ROOT = Path(__file__).resolve().parent
#       2 print(ROOT)
#
# NameError: name '__file__' is not defined

# %%
from road_segmentation_model import build_road_segmentation_model

def load_model(
    weights_path: Path,
    compound_coef: int,
    backbone_name: str | None,
    device: torch.device,
    device_id: int,
    use_ddp: bool,
) -> torch.nn.Module:
    return build_road_segmentation_model(
        weights_path=weights_path,
        compound_coef=compound_coef,
        backbone_name=backbone_name,
        device=device,
        device_id=device_id,
        use_ddp=use_ddp,
    )

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TORCH_USE_CUDA_DSA"]= "1"


model = "hybridnets-d3_19_43740_best.pth"
device = torch.device("cuda")
new_model = load_model(model, 3, None, device,0, False)
# Out:
# Loading model onto cuda
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 8
#       4
#       5
#       6 model = "hybridnets-d3_19_43740_best.pth"
#       7 device = torch.device("cuda")
# ----> 8 new_model = load_model(model, 3, None, device,0, False)
#
# Cell In[32], line 11, in load_model(weights_path, compound_coef, backbone_name, device, device_id, use_ddp)
#       7     device: torch.device,
#       8     device_id: int,
#       9     use_ddp: bool,
#      10 ) -> torch.nn.Module:
# ---> 11     return build_road_segmentation_model(
#      12         weights_path=weights_path,
#      13         compound_coef=compound_coef,
#      14         backbone_name=backbone_name,
#
# File ~/aman/Autonomous-Bicycle/Send/road_segmentation_model.py:60, in build_road_segmentation_model(weights_path, compound_coef, backbone_name, device, device_id, use_ddp)
# ...
